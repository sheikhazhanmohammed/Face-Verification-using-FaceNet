# %%
#importing functions from .py files
from datasetCreator import dataframeCreator

#import libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
dataFrame = dataframeCreator()

# %%
dataFrame.head()
# Out:
#                                                image         name
# 0  [[[146, 137, 128], [147, 138, 129], [148, 139,...  Ahn Bo Hyun
# 1  [[[215, 206, 202], [215, 206, 202], [215, 206,...  Ahn Bo Hyun
# 2  [[[126, 157, 208], [126, 157, 208], [127, 158,...  Ahn Bo Hyun
# 3  [[[144, 156, 180], [143, 155, 179], [142, 154,...  Ahn Bo Hyun
# 4  [[[106, 126, 143], [105, 125, 142], [107, 125,...  Ahn Bo Hyun

# %%
dataFrame.tail()
# Out:
#                                                  image        name
# 135  [[[255, 255, 254], [255, 255, 254], [255, 255,...  Zayn Malik
# 136  [[[122, 107, 91], [122, 107, 91], [122, 107, 9...  Zayn Malik
# 137  [[[236, 221, 229], [235, 220, 228], [236, 220,...  Zayn Malik
# 138  [[[0, 3, 8], [1, 4, 9], [1, 4, 9], [0, 3, 8], ...  Zayn Malik
# 139  [[[86, 98, 104], [87, 99, 105], [88, 98, 105],...  Zayn Malik

# %%
index = np.random.randint(0,100)
image, name = dataFrame.iloc[index]
print("Showing image belonging to: ", name)
plt.imshow(image)
# Out:
# Showing image belonging to:  Mark Zukerberg
